# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq

url = 'https://en.wikipedia.org/wiki/1988_Suzuka_500_km'
url = 'https://killedbypolice.net/kbp2019/'

site = uReq(url)
site.read()
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>1988 Suzuka 500 km - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"87f7b038-87d0-4bda-9e95-e33cb6623607","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"1988_Suzuka_500_km","wgTitle":"1988 Suzuka 500 km","wgCurRevisionId":951752177,"wgRevisionId":951752177,"wgArticleId":40252634,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use dmy dates from February 2015","All Japan Sports Prototype Championship","International Suzuka 500km"],"wgPageContentLanguage":"en","wgPageCo
# ...
