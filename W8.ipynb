# %% [markdown]
# ## Load the website into a bs4-object (only first page)

# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen, Request

# Tablets on a webshop:
url = 'https://www.pc-lager.dk/en/category/computeretablets/tabletterminal'
# Make sure we don't get blocked for being a bot:
req = Request(url, headers = {'User-Agent': 'Mozilla/5.0'})

# Make the request, read the HTML, close the request:
uClient = urlopen(req)
site_html = uClient.read()
uClient.close()

# Parse the HTML into an object we can query:
site_soup = soup(site_html, "html.parser")

# %% [markdown]
# ## Create empty dataframe with relevant columns

# %%
import pandas as pd

tablet_df = pd.DataFrame(columns = ('manufacturer', 'device', 'dkk'))

# %% [markdown]
# ## Find data in bs4-object and add to our dataframe

# %%
# Find every product (a DIV with the class of 'product-grid-item-content'):
tablets = site_soup.findAll('div', { 'class': 'product-grid-item-content' })

for tablet in tablets:
    # Dot syntax for traversing (the first) tag with the given tagname
    # .find/.findAll to query something specific:
    tablet_brand = tablet.ul.findAll('li')[2].a.text.strip() # .strip() to remove whitespace from text
    tablet_name = tablet.h2.a['data-product-name'] # Get the value inside a tag's properties
    tablet_price = int(tablet.find('span', { 'class': 'price' })['data-price']) # Convert to int
    
    # Add data as a single row to our dataframe:
    tablet_df = tablet_df.append(
        { 'manufac': tablet_brand, 'manufacturer': tablet_name, 'dkk': tablet_price },
        ignore_index = True
    )

# We can now work with our data:
tablet_df
# Out:
#                   brand                                               name  \
# 0                 Apple  Apple 10.2-inch iPad Wi-Fi 10.2" Sølv Apple iP...
# 1                 Apple  Apple 10.2-inch iPad Wi-Fi 10.2" Grå Apple iPadOS
# 2                 Apple  Apple 10.2-inch iPad Wi-Fi 10.2" Guld Apple iP...
# 3               Samsung  Samsung Galaxy Tab A (2019) 10.1" Guld Android...
# 4                 Apple  Apple 10.2-inch iPad Wi-Fi 10.2" Guld Apple iP...
# 5               Samsung    Samsung Galaxy Tab S6 Lite 10.4" Blå Android 10
# 6                Lenovo  Lenovo Tab M10 FHD  (2nd Gen) ZA5T 10.3" Grå A...
# 7            Amazon.com                   Amazon Kindle Paperwhite 6" Sort
# 8                Lenovo             Lenovo Tab M10 ZA4G 10.1" Sort Android
# 9               Samsung  Samsung Galaxy Tab A (2019) 10.1" Sort Android...
# 10                Apple  Apple 10.2-inch iPad Wi-Fi 10.2" Sølv Apple iP...
# 11              Samsung  Samsung Galaxy Tab A (2019) 10.1" Sølv Android...
# 12                Apple       Apple iPad Pro Wi-Fi 12.9" Sølv Apple iPadOS
# 13                Apple        Apple iPad Pro Wi-Fi 12.9" Grå Apple iPadOS
# 14              Samsung  Samsung Galaxy Tab A (2019) 10.1" Sort Android...
# 15                Apple  Apple 11-inch iPad Pro Wi-Fi 11" Grå Apple iPadOS
# 16                Apple       Apple iPad Air Wi-Fi 10.5" Sølv Apple iOS 12
# 17            Microsoft  Microsoft Surface Pro 7 12.3" Sølv Windows 10 ...
# 18  Huawei Technologies   HUAWEI MediaPad T5 10.1" Sort Android 8.0 (Oreo)
# 19              Samsung  Samsung Galaxy Tab S5e 10.5" Sort Android 9.0 ...
# 20                Apple  Apple 10.2-inch iPad Wi-Fi  Cellular 10.2" Grå...
# 21               Lenovo  Lenovo Tab M10 FHD  (2nd Gen) ZA5T 10.3" Grå A...
# 22              Samsung  Samsung Galaxy Tab S5e 10.5" Sølv Android 9.0 ...
# 23              Samsung  Samsung Galaxy Tab A (2019) 10.1" Sølv Android...
#
#      dkk
# 0   3069
# 1   3939
# 2   3619
# 3   1479
# 4   3009
# 5   2549
# 6   1699
# 7   1009
# 8   1109
# 9   1839
# 10  3799
# 11  1529
# 12  8739
# 13  8859
# 14  1529
# 15  7179
# 16  4359
# 17  7779
# 18  1479
# 19  3069
# 20  5089
# 21  1789
# 22  3159
# 23  1839
